# %%
import numpy as np
import pandas as pd
import os

from langchain_core.output_parsers import StrOutputParser

#Configuracion splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

#Configuracion LLM - GPT
from langchain_google_genai import ChatGoogleGenerativeAI

#Configuracion obtener APU desde secrets desde google Colab
from google.colab import userdata
GEMINI_API_KEY = userdata.get('AIzaSyASvL_jSJnND6UCdZE-rQwIHnjXbiZAlVg')
os.environ["AIzaSyASvL_jSJnND6UCdZE-rQwIHnjXbiZAlVg"] = GEMINI_API_KEY

# Configurar el modelo de Google
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest")

# Verifico si funciona
print(llm.invoke("Hola Gemini").content)

#uv pip install langchain langgraph langchain-google-genai langchain-ollama pypdf matplotlib numpy pandas notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 14
#      11 from langchain_google_genai import ChatGoogleGenerativeAI
#      13 #Configuracion obtener APU desde secrets desde google Colab
# ---> 14 from google.colab import userdata
#      15 GEMINI_API_KEY = userdata.get('AIzaSyASvL_jSJnND6UCdZE-rQwIHnjXbiZAlVg')
#      16 os.environ["AIzaSyASvL_jSJnND6UCdZE-rQwIHnjXbiZAlVg"] = GEMINI_API_KEY
#
# ModuleNotFoundError: No module named 'google.colab'
